# %%
import requests
import pandas as pd


tmap_list = pd.read_excel('관광지 주소 추가 전.xlsx')
visitJ = pd.read_csv('visitJeju_areaCode.csv', sep='\t', encoding='utf-8')

# df = pd.DataFrame(['tour','address','long','lat'])


df = pd.merge(tmap_list,visitJ,left_on='관광지명', right_on='title', how = 'left')
df.to_excel('티맵관광지목록_주소변경.xlsx', encoding='utf-8')




# headers = {"Authorization": "KakaoAK 5d6bbf017da7a866d48f509f80016557"}
# input_file = pd.read_excel('티맵네비게이션_관광지.xlsx')

# df = pd.DataFrame(columns=['areacode','tour','address','longtitde','latitude'])
# df['tour'] = input_file['관광지명']


# def adr():
#     for i in df['tour']:
#         # url= 'https://dapi.kakao.com/v2/local/keyword.json?query={1100고지 코스}.format('+i+')'
#         url= 'https://dapi.kakao.com/v2/local/search/keyword.json?query='+i
#         url= 'https://dapi.kakao.com/v2/local/search/address.json?query='+'서귀포잠수함'
#         result = requests.get(url, headers=headers).json()
#         print(result)
#         # address = result.get('address').get('address_name')
#         # long = result.get('address').get('x')
#         # lat = result.get('address').get('y')
#         # address_dong = result.get('road').get('region_3depth_name')
#         break
#     return 


# adr()

# %%
import pandas as pd
df_tmap = pd.read_excel('티맵관광지목록_정리 완료.xlsx')
df_visitj = pd.read_excel('visitJejuList.xlsx')

# %%
df_tmap.info()
df_visitj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 484 entries, 0 to 483
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   num        484 non-null    int64
#  1   관광지명       484 non-null    object
#  2   도로명주소      484 non-null    object
#  3   중분류 카테고리   484 non-null    object
#  4   소분류 카테고리   484 non-null    object
#  5   area_code  484 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 22.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1098 entries, 0 to 1097
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          1098 non-null   object
#  1   contentsid     1098 non-null   object
#  2   latitude       1098 non-null   object
#  3   longitude      1098 non-null   object
#  4   address        1098 non-null   object
#  5   roadaddress    1098 non-null   object
# ...

# %%
df = pd.merge(df_tmap, df_visitj, how='left', left_on='관광지명', right_on='title')
df
# Out:
#      num        관광지명                                 도로명주소       중분류 카테고리  \
# 0      1   1100고지 코스               제주특별자치도 서귀포시 1100로 1555          기타관광지
# 1      2    1100고지습지                제주특별자치도 서귀포시 색달동 산 1-2          기타관광지
# 2      3   5.16도로숲터널            제주특별자치도 서귀포시 남원읍 신례리 산 2-1          기타관광지
# 3      4      9.81파크            제주특별자치도 제주시 애월읍 천덕로 880-24          휴양관광지
# 4      5      J1카트클럽           제주특별자치도 제주시 연북로 424 J1빌딩 1층  레포츠(육상/해상/항공)
# ..   ...         ...                                   ...            ...
# 486  480    황우지해안열두굴                제주특별자치도 서귀포시 서홍동 764-1          자연관광지
# 487  481          휴림                 제주 제주시 애월읍 광령남서길 40-0          기타관광지
# 488  482     휴애리수국축제  제주특별자치도 서귀포시 남원읍 신례동로 256 (신례리, 휴애리)          기타관광지
# 489  483   휴애리자연생활공원  제주특별자치도 서귀포시 남원읍 신례동로 256 (신례리, 휴애리)          자연관광지
# 490  484  힐링카약파크비체올린                     제주시 한경면 판조로 253-6  레포츠(육상/해상/항공)
#
#     소분류 카테고리  area_code       title            contentsid    latitude  \
# ...

# %%
df.to_excel('제주도관광지정보.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 0 to 490
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   num            491 non-null    int64
#  1   관광지명           491 non-null    object
#  2   도로명주소          491 non-null    object
#  3   중분류 카테고리       491 non-null    object
#  4   소분류 카테고리       491 non-null    object
#  5   area_code      491 non-null    int64
#  6   title          346 non-null    object
#  7   contentsid     346 non-null    object
#  8   latitude       346 non-null    object
#  9   longitude      346 non-null    object
#  10  address        346 non-null    object
#  11  roadaddress    346 non-null    object
#  12  tag            346 non-null    object
#  13  alltag         346 non-null    object
#  14  introduction   346 non-null    object
#  15  sbst           341 non-null    object
#  16  imgpath        346 non-null    object
# ...
